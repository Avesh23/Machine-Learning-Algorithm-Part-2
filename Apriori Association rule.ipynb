# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_rows",500)

# %%
data = pd.read_csv("D:\Data_Analytics\Machine learning\Datasets\groceries.csv")

# %%
data.head()
# Out:
#        citrus fruit semi-finished bread     margarine   ready soups  \
# 0    tropical fruit              yogurt        coffee           NaN
# 1        whole milk                 NaN           NaN           NaN
# 2         pip fruit              yogurt  cream cheese  meat spreads
# 3        rolls/buns                 NaN           NaN           NaN
# 4  other vegetables            UHT-milk    rolls/buns  bottled beer
#
#            Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# 2                 NaN        NaN        NaN        NaN        NaN        NaN
# 3                 NaN        NaN        NaN        NaN        NaN        NaN
# 4  liquor (appetizer)        NaN        NaN        NaN        NaN        NaN
#
#    ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...         NaN         NaN         NaN         NaN         NaN
# 2  ...         NaN         NaN         NaN         NaN         NaN
# 3  ...         NaN         NaN         NaN         NaN         NaN
# 4  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (9832, 32)

# %% [markdown]
# ## removing nan values using list over list method

# %%
market=[]
for i in range (0,data.shape[0]):
    cus=[]
    for j in data.columns:
        if type(data[j][i])==str:
            cus.append(data[j][i])
            market.append(cus)

# %%
l=[]
for i in market:
    for j in i:
        l.append(j)

# %% [markdown]
# ## Most selling product

# %%
import collections

# %%
p = collections.Counter(l)

# %%
d={"item name":p.keys(),"values":p.values()}

# %%
pd.DataFrame(d).sort_values(by=["values"],ascending=False).head()
# Out:
#            item name  values
# 3         whole milk   16985
# 8   other vegetables   14164
# 7         rolls/buns   10855
# 1             yogurt   10308
# 24              soda   10096

# %% [markdown]
# ## which products are bought together

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()

# %%
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 43349                  False     False             False             False
# 43350                  False     False             False             False
# 43351                  False     False             False             False
# 43352                  False     False             False             False
# 43353                  False     False             False             False
#
#        baby cosmetics  baby food   bags  baking powder  bathroom cleaner  \
# 0               False      False  False          False             False
# 1               False      False  False          False             False
# 2               False      False  False          False             False
# 3               False      False  False          False             False
# 4               False      False  False          False             False
# ...               ...        ...    ...            ...               ...
# 43349           False      False  False          False             False
# 43350           False      False  False          False             False
# 43351           False      False  False          False             False
# 43352           False      False  False          False             False
# 43353           False      False  False          False             False
#
#         beef  ...  turkey  vinegar  waffles  whipped/sour cream  whisky  \
# 0      False  ...   False    False    False               False   False
# 1      False  ...   False    False    False               False   False
# 2      False  ...   False    False    False               False   False
# 3      False  ...   False    False    False               False   False
# 4      False  ...   False    False    False               False   False
# ...      ...  ...     ...      ...      ...                 ...     ...
# 43349  False  ...   False     True    False               False   False
# 43350  False  ...   False     True    False               False   False
# 43351  False  ...   False     True    False               False   False
# 43352  False  ...   False     True    False               False   False
# 43353  False  ...   False     True    False               False   False
#
#        white bread  white wine  whole milk  yogurt  zwieback
# 0            False       False       False    True     False
# 1            False       False       False    True     False
# 2            False       False       False    True     False
# 3            False       False        True   False     False
# 4            False       False       False    True     False
# ...            ...         ...         ...     ...       ...
# 43349        False       False       False   False     False
# 43350        False       False       False   False     False
# 43351        False       False       False   False     False
# 43352        False       False       False   False     False
# 43353        False       False       False   False     False
#
# [43354 rows x 169 columns]

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(df,min_support=0.05,use_colnames=True,max_len=3)
# Out:
#      support                                         itemsets
# 0   0.053098                                       (UHT-milk)
# 1   0.091987                                           (beef)
# 2   0.059971                                        (berries)
# 3   0.098837                                   (bottled beer)
# 4   0.161577                                  (bottled water)
# 5   0.103981                                    (brown bread)
# 6   0.107510                                         (butter)
# 7   0.068990                                    (canned beer)
# 8   0.077594                                        (chicken)
# 9   0.085874                                      (chocolate)
# 10  0.143747                                   (citrus fruit)
# 11  0.089980                                         (coffee)
# 12  0.074272                                   (cream cheese)
# 13  0.095701                                           (curd)
# 14  0.067629                                        (dessert)
# 15  0.119920                                  (domestic eggs)
# 16  0.098814                                    (frankfurter)
# 17  0.091203                              (frozen vegetables)
# 18  0.129423                          (fruit/vegetable juice)
# 19  0.050584                                            (ham)
# 20  0.061609                                 (hamburger meat)
# 21  0.062163                               (hygiene articles)
# 22  0.067237                       (long life bakery product)
# 23  0.104650                                      (margarine)
# 24  0.096185                                        (napkins)
# 25  0.113830                                     (newspapers)
# 26  0.054505                                            (oil)
# 27  0.059741                                         (onions)
# 28  0.326706                               (other vegetables)
# 29  0.137842                                         (pastry)
# 30  0.134059                                      (pip fruit)
# 31  0.096969                                           (pork)
# 32  0.250381                                     (rolls/buns)
# 33  0.198067                                (root vegetables)
# 34  0.063085                                    (salty snack)
# 35  0.152812                                        (sausage)
# 36  0.146446                                  (shopping bags)
# 37  0.051183                                  (sliced cheese)
# 38  0.232874                                           (soda)
# 39  0.063477                                          (sugar)
# 40  0.186165                                 (tropical fruit)
# 41  0.067030                                        (waffles)
# 42  0.133229                             (whipped/sour cream)
# 43  0.077871                                    (white bread)
# 44  0.391775                                     (whole milk)
# 45  0.237764                                         (yogurt)
# 46  0.055128                (bottled water, other vegetables)
# 47  0.051206                            (bottled water, soda)
# 48  0.067560                      (bottled water, whole milk)
# 49  0.051299                       (butter, other vegetables)
# 50  0.064123                             (butter, whole milk)
# 51  0.064239                 (citrus fruit, other vegetables)
# 52  0.066361                       (whole milk, citrus fruit)
# 53  0.055750                               (whole milk, curd)
# 54  0.053928                (domestic eggs, other vegetables)
# 55  0.066891                      (whole milk, domestic eggs)
# 56  0.052406        (fruit/vegetable juice, other vegetables)
# 57  0.061886              (fruit/vegetable juice, whole milk)
# 58  0.051529                          (whole milk, margarine)
# 59  0.051921                       (pastry, other vegetables)
# 60  0.060825                    (other vegetables, pip fruit)
# 61  0.087950                   (other vegetables, rolls/buns)
# 62  0.105273              (root vegetables, other vegetables)
# 63  0.061102                      (sausage, other vegetables)
# 64  0.070213                         (other vegetables, soda)
# 65  0.084583               (other vegetables, tropical fruit)
# 66  0.069221           (other vegetables, whipped/sour cream)
# 67  0.158232                   (whole milk, other vegetables)
# 68  0.100221                       (yogurt, other vegetables)
# 69  0.066130                             (whole milk, pastry)
# 70  0.067283                          (whole milk, pip fruit)
# 71  0.053467                    (root vegetables, rolls/buns)
# 72  0.052729                            (sausage, rolls/buns)
# 73  0.064908                               (soda, rolls/buns)
# 74  0.051322                     (tropical fruit, rolls/buns)
# 75  0.106588                         (whole milk, rolls/buns)
# 76  0.070328                             (yogurt, rolls/buns)
# 77  0.052683                (root vegetables, tropical fruit)
# 78  0.106864                    (whole milk, root vegetables)
# 79  0.062140                        (yogurt, root vegetables)
# 80  0.064792                            (sausage, whole milk)
# 81  0.081538                               (whole milk, soda)
# 82  0.058311                                   (yogurt, soda)
# 83  0.093648                     (whole milk, tropical fruit)
# 84  0.069198                         (yogurt, tropical fruit)
# 85  0.073626                 (whole milk, whipped/sour cream)
# 86  0.050837                     (yogurt, whipped/sour cream)
# 87  0.121442                             (whole milk, yogurt)
# 88  0.059810  (whole milk, root vegetables, other vegetables)
# 89  0.058611           (yogurt, other vegetables, whole milk)
